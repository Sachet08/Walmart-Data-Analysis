# %% [markdown]
# # **Walmart**

# %% [markdown]
# ### Business Understanding
#
#
# #### Walmart Inc. is an American multinational retail corporation that operates a chain of hypermarkets, discount department stores, and grocery stores from the United States, headquartered in Bentonville, Arkansas
# ![walmart.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Analysing the sales of walmart (eg: analysing weekly sales, which store or department sells most etc.)**

# %% [markdown]
# ## **Data Analysis and Visualization**

# %% [markdown]
# #### Importing all the required libraries and packages.

# %%
# Analysis and Mathematical Libraries
import pandas as pd
import numpy as np

# Visualization Libraries
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# %% [markdown]
# #### Reading all the csv files as dataframes using pd.read_csv method.

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
stores_df = pd.read_csv("stores.csv")
features_df = pd.read_csv("features.csv")

# %% [markdown]
# ### Analysing each imported data frames.

# %% [markdown]
# #### Viewing the data in train_df

# %% [markdown]
# ####Weekly sales data in accordance with store department and date.

# %%
train_df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
# Viewing the info eaach column in the dataframe.
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
# Describing the data in train dataframe.
train_df.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
# Analysing null values in each column.
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %% [markdown]
# ### Viewing the test_df

# %%
test_df.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
test_df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'IsHoliday'], dtype='object')

# %%
# Describing the dataset in the test dataframe.
test_df.describe()
# Out:
#                Store           Dept
# count  115064.000000  115064.000000
# mean       22.238207      44.339524
# std        12.809930      30.656410
# min         1.000000       1.000000
# 25%        11.000000      18.000000
# 50%        22.000000      37.000000
# 75%        33.000000      74.000000
# max        45.000000      99.000000

# %%
# Analysing null values in each column.
test_df.isnull().sum()
# Out:
# Store        0
# Dept         0
# Date         0
# IsHoliday    0
# dtype: int64

# %% [markdown]
# ###Viewing the features data frame
#
# ---

# %%
features_df.head()
# Out:
#    Store        Date  Temperature  ...         CPI  Unemployment  IsHoliday
# 0      1  2010-02-05        42.31  ...  211.096358         8.106      False
# 1      1  2010-02-12        38.51  ...  211.242170         8.106       True
# 2      1  2010-02-19        39.93  ...  211.289143         8.106      False
# 3      1  2010-02-26        46.63  ...  211.319643         8.106      False
# 4      1  2010-03-05        46.50  ...  211.350143         8.106      False
#
# [5 rows x 12 columns]

# %%
# Viewing the info of each column in the dataframe.
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
# Describing the dataset in the feature dataframe
features_df.describe()
# Out:
#              Store  Temperature  ...          CPI  Unemployment
# count  8190.000000  8190.000000  ...  7605.000000   7605.000000
# mean     23.000000    59.356198  ...   172.460809      7.826821
# std      12.987966    18.678607  ...    39.738346      1.877259
# min       1.000000    -7.290000  ...   126.064000      3.684000
# 25%      12.000000    45.902500  ...   132.364839      6.634000
# 50%      23.000000    60.710000  ...   182.764003      7.806000
# 75%      34.000000    73.880000  ...   213.932412      8.567000
# max      45.000000   101.950000  ...   228.976456     14.313000
#
# [8 rows x 10 columns]

# %%
# Analysing the null values in each column.
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %% [markdown]
# ### Viewing the stores dataframe

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
# Describing the dataset in the stores dataframe
stores_df.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
# Analysing null values in each columns
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %% [markdown]
# #### Creating a new dataframe by merging (inner) features data frame to stores data frame on Store for analysis purpose

# %%
dataset_df = features_df.merge(stores_df, how = 'inner', on = 'Store')
dataset_df.head()
# Out:
#    Store        Date  Temperature  ...  IsHoliday  Type    Size
# 0      1  2010-02-05        42.31  ...      False     A  151315
# 1      1  2010-02-12        38.51  ...       True     A  151315
# 2      1  2010-02-19        39.93  ...      False     A  151315
# 3      1  2010-02-26        46.63  ...      False     A  151315
# 4      1  2010-03-05        46.50  ...      False     A  151315
#
# [5 rows x 14 columns]

# %%
# Gathering the info regarding the columns of new dataset
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 903.8+ KB

# %% [markdown]
# ##### Converting date to date time object.

# %%
# Importing datetime 
from datetime import datetime
# Converting date to datetime object
dataset_df['Date'] = pd.to_datetime(dataset_df['Date'])
train_df['Date'] = pd.to_datetime(train_df['Date'])
test_df['Date'] = pd.to_datetime(test_df['Date'])
#Extract week and year from the date and make them into new columns.
dataset_df['week'] = dataset_df.Date.dt.isocalendar().week
dataset_df['year'] = dataset_df.Date.dt.isocalendar().year

# %%
dataset_df.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  ...  Type    Size  week  year
# 8185     45 2013-06-28        76.05       3.639  ...     B  118221    26  2013
# 8186     45 2013-07-05        77.50       3.614  ...     B  118221    27  2013
# 8187     45 2013-07-12        79.37       3.614  ...     B  118221    28  2013
# 8188     45 2013-07-19        82.84       3.737  ...     B  118221    29  2013
# 8189     45 2013-07-26        76.06       3.804  ...     B  118221    30  2013
#
# [5 rows x 16 columns]

# %% [markdown]
# ##### Creating a new df(variabe) by merging (inner) the train_df and the new data frame dataset_df on  store, date and IsHoliday columns and sorting the values by Store, department and date.

# %%
train_df_1 = train_df.merge(dataset_df, how ='inner', on =['Store', 'Date', 'IsHoliday']).sort_values(by =['Store','Dept','Date']).reset_index(drop=True)

# %%
train_df_1.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  ...  Type    Size  week  year
# 0      1     1 2010-02-05      24924.50  ...     A  151315     5  2010
# 1      1     1 2010-02-12      46039.49  ...     A  151315     6  2010
# 2      1     1 2010-02-19      41595.55  ...     A  151315     7  2010
# 3      1     1 2010-02-26      19403.54  ...     A  151315     8  2010
# 4      1     1 2010-03-05      21827.90  ...     A  151315     9  2010
#
# [5 rows x 18 columns]

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## **Visualizations**

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------
# #### Defining a function scatter to plot the scatter plot with the data of the column specified as the function parameter in x axis and weekly sales as the y values.

# %% [markdown]
# ## **1) Scatter plot**

# %%
def scatter(train_df_1, column):
    # ploting the figure
    plt.figure()
    # ploting the scatter plot with data from the specified column in x axis and weekly sales in y axis
    plt.scatter(train_df[column], train_df['Weekly_Sales'])
    # labeling y label as weekly_sales
    plt.ylabel('Weekly_Sales')
    # labeling the xlabel as the column specified as parameter in the function
    plt.xlabel(column)

# %%
# ploting a scatter plot of weekly sales with respect to Store
scatter(train_df_1, 'Store')
# ploting a scatter plot of weekly sales with respect to Department
scatter(train_df_1, 'Dept')

# %% [markdown]
# The scatter plots of weekly sales with respect to stores and department, it is clear that departments between 60 and 80 are performing better.

# %% [markdown]
# ## **2) 3 line plots for weekly sales for the years**

# %%
# Filtering out mean weekly sales for the year 2010
weekly_sales_2010 = train_df_1[train_df_1['year'] ==  2010]['Weekly_Sales'].groupby(train_df_1['week']).mean()
# Ploting a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# This is the line plot for weekly sales in the year 2010

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %%
# Filtering out mean weekly sales for the year 2011
weekly_sales_2011 = train_df_1[train_df_1['year'] ==  2011]['Weekly_Sales'].groupby(train_df_1['week']).mean()
# Ploting a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values,color='black')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# This is the line plot for weekly sales in the year 2011

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %%
#Filtering out mean weekly sales for the year 2012
weekly_sales_2012 = train_df_1[train_df_1['year'] ==  2012]['Weekly_Sales'].groupby(train_df_1['week']).mean()
#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values,color='violet')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# This is the line plot for weekly sales in the year 2012

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **3) Combined line plots for each year (2010,2011 & 2012)**

# %% [markdown]
# #### Plotting the weekly sales for years 2010,2011,2012 on a single plot to compare the sales values with respect to week.

# %%
# plotting a figure 
plt.figure(figsize= (20, 10))
# Plotting three line plots for weekly sales for each year
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values)
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values)
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values)
plt.grid()
# plot labels and legends
plt.xticks(np.arange(1,60, step= 1))
plt.title('Average Weekly Sales Per Year', fontsize = 20)
plt.xlabel('Week', fontsize = 16)
plt.ylabel('Sales', fontsize = 16)
plt.legend(['2010', '2011','2012'], loc = 'best', fontsize = 16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From the above figure it's clear that the combined line lot that on week 51 of 2010 we have the maximum sale

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **4) Histogram / Normal Distribution**

# %%
f, ax = plt.subplots(figsize=(8, 6))
#Creating a distribution for weekly sales in the dataframe train_df
sns.distplot(train_df['Weekly_Sales'],color='g')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Skewness is a measure of symmetry, or more precisely, the lack of symmetry. A distribution, or data set, is symmetric if it looks the same to the left and right of the center point.
print("Skewness: ", train_df['Weekly_Sales'].skew()) #skewness
# Kurtosis is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution. That is, data sets with high kurtosis tend to have heavy tails, or outliers. Data sets with low kurtosis tend to have light tails, or lack of outliers
print("Kurtosis: ", train_df['Weekly_Sales'].kurt()) #kurtosis
# Out:
# Skewness:  3.2620081854656657
# Kurtosis:  21.49128990832619

# %% [markdown]
# #### The above code is to determine the skew and kurtosis of the normal distribution.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **5) Box Plot**

# %%
# concatinating the type and column from store_df together to find the relation between stores falling under each type and size.
data = pd.concat([stores_df['Type'], stores_df['Size']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
# Plot a box plot to understand the relation between type and size of stores.
fig = sns.boxplot(x='Type', y='Size', data=data)

# %% [markdown]
# From the above box plots we can see that Type A plots are the largest, and has the largest size

# %% [markdown]
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _

# %% [markdown]
# ### **6) Bar chart on dataframe**

# %%
weekly_sales_store = train_df['Weekly_Sales'].groupby(train_df['Store']).mean()

# %% [markdown]
# #### Grouping the train_df by store and computing the mean of weekly_sales for each store.

# %%
weekly_sales_store.head()
# Out:
# Store
# 1    21710.543621
# 2    26898.070031
# 3     6373.033983
# 4    29161.210415
# 5     5053.415813
# Name: Weekly_Sales, dtype: float64

# %%
# Converting the data to a pandas dataframe
weekly_sales_store_df=pd.DataFrame(weekly_sales_store)

# %% [markdown]
# #### Sorting the data frame with respect to weekly sales in Descending order and plotting a var graph on the data frame itself.

# %%
weekly_sales_store_df.sort_values("Weekly_Sales",ascending=False).style.bar(align='left',width=98,color='#3d172e')
# Out:
# <style  type="text/css" >
# #T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 98.0%, transparent 98.0%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 96.6%, transparent 96.6%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 95.1%, transparent 95.1%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 89.4%, transparent 89.4%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 87.5%, transparent 87.5%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 85.3%, transparent 85.3%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 79.2%, transparent 79.2%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 67.6%, transparent 67.6%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 66.8%, transparent 66.8%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 63.9%, transparent 63.9%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 61.3%, transparent 61.3%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 59.0%, transparent 59.0%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 58.6%, transparent 58.6%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 57.0%, transparent 57.0%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 55.8%, transparent 55.8%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 54.7%, transparent 54.7%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 51.8%, transparent 51.8%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 45.3%, transparent 45.3%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 42.8%, transparent 42.8%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 40.6%, transparent 40.6%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 39.3%, transparent 39.3%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 38.1%, transparent 38.1%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 35.1%, transparent 35.1%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 34.9%, transparent 34.9%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 33.9%, transparent 33.9%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 33.5%, transparent 33.5%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 32.4%, transparent 32.4%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 31.7%, transparent 31.7%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 26.5%, transparent 26.5%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 25.6%, transparent 25.6%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 25.0%, transparent 25.0%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 21.1%, transparent 21.1%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 21.0%, transparent 21.0%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 15.8%, transparent 15.8%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row34_col0,#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 14.9%, transparent 14.9%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 14.2%, transparent 14.2%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 13.2%, transparent 13.2%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 12.4%, transparent 12.4%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 11.3%, transparent 11.3%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3d172e 9.8%, transparent 9.8%);
#         }#T_e7bc922a_0f5b_11ec_98dd_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-

# %% [markdown]
# Store number 20 has the highest weekly sales (20508.301592)

# %% [markdown]
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _

# %% [markdown]
# #### Sorting the data frame with respect to weekly sales in Ascending order and plotting a var graph on the data frame itself.

# %%
weekly_sales_store_df.sort_values("Weekly_Sales",ascending=True).style.bar(align='left',width=98,color='#173d3c')
# Out:
# <style  type="text/css" >
# #T_495a439c_0f5c_11ec_98dd_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 2.7%, transparent 2.7%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 3.9%, transparent 3.9%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 5.3%, transparent 5.3%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 9.8%, transparent 9.8%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 11.3%, transparent 11.3%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 12.4%, transparent 12.4%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 13.2%, transparent 13.2%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 14.2%, transparent 14.2%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row9_col0,#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 14.9%, transparent 14.9%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 15.8%, transparent 15.8%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 21.0%, transparent 21.0%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 21.1%, transparent 21.1%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 25.0%, transparent 25.0%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 25.6%, transparent 25.6%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 26.5%, transparent 26.5%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 31.7%, transparent 31.7%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 32.4%, transparent 32.4%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 33.5%, transparent 33.5%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 33.9%, transparent 33.9%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 34.9%, transparent 34.9%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 35.1%, transparent 35.1%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 38.1%, transparent 38.1%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 39.3%, transparent 39.3%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 40.6%, transparent 40.6%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 42.8%, transparent 42.8%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 45.3%, transparent 45.3%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 51.8%, transparent 51.8%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 54.7%, transparent 54.7%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 55.8%, transparent 55.8%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 57.0%, transparent 57.0%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 58.6%, transparent 58.6%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 59.0%, transparent 59.0%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 61.3%, transparent 61.3%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 63.9%, transparent 63.9%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 66.8%, transparent 66.8%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 67.6%, transparent 67.6%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 79.2%, transparent 79.2%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 85.3%, transparent 85.3%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 87.5%, transparent 87.5%);
#         }#T_495a439c_0f5c_11ec_98dd_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#173d3c 89.4%, transparent 89.4%);
#         }#T_495a439c_0f5c_11ec_98dd_02

# %% [markdown]
#  Store number 5 has the least weekly sales (5053.415813)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **7) Bar graph for mean weekly sales for each store.**

# %% [markdown]
# ## Plotting a bar graph with store number as x values and mean weekly sales for that store as the y values.

# %%
#Plotting the figure.
plt.figure(figsize= (25, 12))
#Creating a barplot with stores in x axis and mean weekly sales for each store as y values.
sns.barplot(weekly_sales_store.index, weekly_sales_store.values,palette='dark')
#plot a grid
plt.grid()
#Give title,x and y labels for the plot
plt.title('Average Weekly Sales Per Store', fontsize = 20)
plt.xlabel('Store Number', fontsize = 16)
plt.ylabel('Sales Per Store ', fontsize = 16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - From the plot we can see that store number 20 has the highest mean weekly sales, followed by store 4 and then store 14.

# %% [markdown]
# #### Grouping the train_df by Department and computing the mean of weekly_sales for each Department.

# %%
weekly_sales_Dept = train_df['Weekly_Sales'].groupby(train_df['Dept']).mean()

# %%
# Converting to a pandas dataframe
weekly_sales_Dept_df= pd.DataFrame(weekly_sales_Dept)

# %%
weekly_sales_Dept_df
# Out:
#       Weekly_Sales
# Dept
# 1     19213.485088
# 2     43607.020113
# 3     11793.698516
# 4     25974.630238
# 5     21365.583515
# ...            ...
# 95    69824.423080
# 96    15210.942761
# 97    14255.576919
# 98     6824.694889
# 99      415.487065
#
# [81 rows x 1 columns]

# %% [markdown]
# #### Sorting the data frame with respect to weekly sales in Descending order and plotting a var graph on the data frame itself to get a idea about the data.

# %%
weekly_sales_Dept_df.sort_values("Weekly_Sales",ascending=False).style.bar(align='left',width=98,color='#d65f5f')
# Out:
# <style  type="text/css" >
# #T_26d18910_0f5d_11ec_98dd_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 91.0%, transparent 91.0%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 79.6%, transparent 79.6%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.9%, transparent 65.9%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.2%, transparent 59.2%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.9%, transparent 58.9%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.5%, transparent 58.5%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.8%, transparent 56.8%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.9%, transparent 43.9%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.5%, transparent 43.5%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 40.0%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 39.3%, transparent 39.3%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.2%, transparent 35.2%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.5%, transparent 31.5%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.2%, transparent 31.2%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.6%, transparent 28.6%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.8%, transparent 27.8%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.3%, transparent 26.3%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.0%, transparent 26.0%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.9%, transparent 23.9%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.4%, transparent 20.4%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row23_col0,#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.2%, transparent 20.2%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.8%, transparent 19.8%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.9%, transparent 18.9%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row28_col0,#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.6%, transparent 18.6%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.0%, transparent 18.0%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.5%, transparent 17.5%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.9%, transparent 15.9%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.4%, transparent 15.4%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row34_col0,#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.0%, transparent 14.0%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.3%, transparent 13.3%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.7%, transparent 11.7%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.6%, transparent 10.6%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.7%, transparent 9.7%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
#         }#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row42_col0,#T_26d18910_0f5d_11ec_98dd_0242ac1c0002row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.9%, transparent 8.9%);

# %% [markdown]
# The department 92 has the highest weekly sales

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ####  Sorting the data frame with respect to weekly sales in Ascending order and plotting a var graph on the data frame itself.

# %%
weekly_sales_Dept_df.sort_values("Weekly_Sales").style.bar(align='left',width=98,color='#bfff00')
# Out:
# <style  type="text/css" >
# #T_65314830_0f5d_11ec_98dd_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row1_col0,#T_65314830_0f5d_11ec_98dd_0242ac1c0002row2_col0,#T_65314830_0f5d_11ec_98dd_0242ac1c0002row3_col0,#T_65314830_0f5d_11ec_98dd_0242ac1c0002row4_col0,#T_65314830_0f5d_11ec_98dd_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 0.0%, transparent 0.0%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 0.2%, transparent 0.2%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 0.4%, transparent 0.4%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 0.5%, transparent 0.5%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 0.6%, transparent 0.6%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 0.8%, transparent 0.8%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 0.9%, transparent 0.9%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 1.8%, transparent 1.8%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 2.1%, transparent 2.1%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 2.2%, transparent 2.2%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 2.5%, transparent 2.5%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row16_col0,#T_65314830_0f5d_11ec_98dd_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 2.6%, transparent 2.6%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 3.0%, transparent 3.0%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 3.1%, transparent 3.1%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 3.5%, transparent 3.5%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 3.8%, transparent 3.8%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 4.1%, transparent 4.1%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 4.4%, transparent 4.4%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 4.8%, transparent 4.8%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 5.0%, transparent 5.0%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 5.4%, transparent 5.4%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 5.5%, transparent 5.5%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 6.1%, transparent 6.1%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 6.2%, transparent 6.2%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 6.5%, transparent 6.5%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 6.8%, transparent 6.8%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 7.2%, transparent 7.2%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 7.4%, transparent 7.4%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 7.5%, transparent 7.5%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 8.3%, transparent 8.3%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 8.4%, transparent 8.4%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row37_col0,#T_65314830_0f5d_11ec_98dd_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 8.9%, transparent 8.9%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 9.6%, transparent 9.6%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 9.7%, transparent 9.7%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 10.0%, transparent 10.0%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row42_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 10.6%, transparent 10.6%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 11.7%, transparent 11.7%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row44_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 13.3%, transparent 13.3%);
#         }#T_65314830_0f5d_11ec_98dd_0242ac1c0002row45_col0,#T_65314830_0f5d_11ec_98dd_0242ac1c0002row46_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bfff00 14.0%, transparent 1

# %% [markdown]
# ### The department 47 has a cumulative negative value for weekly sales followed by department 43 which has a very low weekly sale of 1.193333

# %% [markdown]
# _ _ _ _ _ _ _ __  __ _ _ ___ _ _ _ _ ___ _ _ _ _  _ _

# %% [markdown]
# ## Plotting a bar graph with Department number as x values and mean weekly sales for that store as the y values.

# %%
#Plot a figure
plt.figure(figsize= (25, 12))
#Creating a barplot with department in x axis and mean weekly sales for each store as y values.
sns.barplot(weekly_sales_Dept.index, weekly_sales_Dept.values)
#plot a grid
plt.grid()
#Give title,x and y labels for the plot
plt.title('Average Weekly Sales Per Department', fontsize = 20)
plt.xlabel('Department', fontsize = 16)
plt.ylabel('Sales', fontsize = 16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# We can see that weekly sales is highest for department 92.

# %% [markdown]
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _  _ _ _ _ _

# %% [markdown]
# ### **8) Series of line plots for mean sales with respect to Departments.**

# %% [markdown]
# #### Creating line plots of mean weekly sales for each department in the dataframe.

# %%
#Creating a data frame grouped by grouping the train_df on department and date.
grouped=train_df.groupby(['Dept','Date']).mean().reset_index()

#Filtering out Department, Date, Weekly sales from the new data frame grouped.
data=grouped[['Dept','Date','Weekly_Sales']]

#Finding out unique values in the department column.
dept=train_df['Dept'].unique()
#Sort the unique values in the column
dept.sort()
#Divide the departments into 4 batches
dept_1=dept[0:20]
dept_2=dept[20:40]
dept_3=dept[40:60]
dept_4=dept[60:]
#Create subplots with 2 rows and 2 columns and adjusting the spacing between the subplots.
fig, ax = plt.subplots(2,2,figsize=(20,10))
fig.subplots_adjust(wspace=0.5, hspace=0.5)
fig.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9)

#For each batch containg departments and for each department in each batch plot the weekly sales in accordance with date.
for i in dept_1 :
    data_1=data[data['Dept']==i]
    ax[0,0].plot(data_1['Date'], data_1['Weekly_Sales'],label='Dept_1_mean_sales')

for i in dept_2 :
    data_1=data[data['Dept']==i]
    ax[0,1].plot(data_1['Date'], data_1['Weekly_Sales'],label='Dept_1_mean_sales')
    
for i in dept_3 :
    data_1=data[data['Dept']==i]
    ax[1,0].plot(data_1['Date'], data_1['Weekly_Sales'],label='Dept_1_mean_sales')    

for i in dept_4 :
    data_1=data[data['Dept']==i]
    ax[1,1].plot(data_1['Date'], data_1['Weekly_Sales'],label='Dept_1_mean_sales')        
    
#Give each subplot a suitable title    
ax[0,0].set_title('Mean sales record by department (0-19)')
ax[0,1].set_title('Mean sales record by department (20-39)')
ax[1,0].set_title('Mean sales record by department (40-59)')
ax[1,1].set_title('Mean sales record by department (60-79)')

#Give each Subplot y and x labels
ax[0,0].set_ylabel('Mean sales With Respect To Specified Departments')
ax[0,0].set_xlabel('Date')
ax[0,1].set_ylabel('Mean sales With Respect To Specified Departments')
ax[0,1].set_xlabel('Date')
ax[1,0].set_ylabel('Mean sales With Respect To Specified Departments')
ax[1,0].set_xlabel('Date')
ax[1,1].set_ylabel('Mean sales With Respect To Specified Departments')
ax[1,1].set_xlabel('Date')
plt.show()

# %% [markdown]
# - The sales level is different by department
#
# - There is some peaked points around January and May, thus indicating high sales during those times.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Histogram / Normal Distribution

# %% [markdown]
# ### Plotting the normal distribution where sales is greator than zero.

# %%
#Data for sales over zero
train_over_zero_sales=train_df[train_df['Weekly_Sales']>0]
#Data for sales less than zero
train_below_zero_sales=train_df[train_df['Weekly_Sales']<=0]
#Natural log of data for sales over zero
sales_over_zero_sales = np.log1p(train_over_zero_sales['Weekly_Sales'])
#plotting a histogram and normal distribution for data with sales over zero.
f, ax = plt.subplots(figsize=(8, 6))
sns.distplot(sales_over_zero_sales)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness: ", sales_over_zero_sales.skew()) #skewness
print("Kurtosis: ", sales_over_zero_sales.kurt()) #kurtosis
# Out:
# Skewness:  -1.2011878481918052
# Kurtosis:  1.5541238937236335

# %% [markdown]
# _ _ _ _ _ _ __ __ _ _ _ _ _ _ _  _ _ _ _ __  _ __ _ _  _ _

# %% [markdown]
# ## **9) Heatmap**

# %% [markdown]
# ### Plotting a heatmap to determine the correlation between columns in the data frame.

# %%
sns.set(style = 'white')
fig, ax = plt.subplots(figsize= (25, 15))
sns.heatmap(train_df_1.corr(), cmap = 'icefire', vmax = 0.3, center = 0, square = True, linewidth= 0.5, cbar_kws = {'shrink': 0.5}, annot = True)

# %% [markdown]
# There are various column that have very week correlation and thus it's always better to drop these columns before modelling since that columns dosent contribute much to the process.
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# Also,some columns are strongly correlated.One of them must be dropped else they would carry similar information to the model.

# %% [markdown]
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _  _ _ _ _ _ _  __ _ _ _ _ _ _ __
